# %% [markdown]
# # 📝 Data Structures & Algorithms — Week 1 Quiz
# ## Foundations & Big O
#
# **Duration:** 30 minutes &nbsp;|&nbsp; **Total:** 100 points
#
# **Instructions:**
# 1. Fill in your **student information** in the cell below and run it.
# 2. Answer each question in its designated code cell.
# 3. **Run every answer cell** after writing your answer.
# 4. When finished, run the **Submit** cell at the bottom.
# 5. You will receive a confirmation email with your auto-graded score.
#
# > ⚠️ **Important:** Run all cells from top to bottom before submitting. Unrun cells will not be captured.
# >
# > ⏰ **Submission window:** Wednesdays 09:00–10:00 (Istanbul time) only.
#
# ---

# %% [markdown]
# ## 📋 Student Information
# Fill in your details below and **run this cell** (Shift+Enter).

# %%
#━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Fill in your info, then run this cell (Shift+Enter)
#━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

STUDENT_ID    = ""     # e.g. "2024001234"
STUDENT_NAME  = ""     # e.g. "Ahmet Yılmaz"
STUDENT_EMAIL = ""     # e.g. "ahmet.yilmaz@istun.edu.tr"
CLASS_CODE    = ""     # code given in class

#━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
import re as _re
_errors = []
if not _re.match(r"^\d{6,12}$", STUDENT_ID):
    _errors.append("❌ Student ID must be 6-12 digits")
if len(STUDENT_NAME.strip().split()) < 2:
    _errors.append("❌ Enter first and last name")
if not STUDENT_EMAIL.strip().lower().endswith("@istun.edu.tr"):
    _errors.append("❌ Use your @istun.edu.tr email")
if len(CLASS_CODE.strip()) < 3:
    _errors.append("❌ Invalid class code")
if _errors:
    for e in _errors: print(e)
    print("\n⚠️  Fix the errors above and run this cell again.")
else:
    print(f"✅ Info OK — {STUDENT_NAME} ({STUDENT_ID})")
    print(f"   {STUDENT_EMAIL}")
    print(f"\n📝 Now answer the questions below.")

# %% [markdown]
# ---
# ## Question 1 — Core Concepts *(20 points)*
#
# Mark each statement as **True** or **False** by writing `"T"` or `"F"` in the cell below.
# For each **False** answer, add a brief explanation as a comment.
#
# | | Statement |
# |---|---|
# | **a)** | Python is primarily a **compiled** programming language. |
# | **b)** | Variable names in Python can start with a digit. |
# | **c)** | Strings (`str`) are **mutable** in Python. |
# | **d)** | The expression `7 / 3` returns an `int` in Python. |
# | **e)** | Lists can contain elements of different data types. |

# %%
# 📝 [Q1] True/False — Write "T" or "F" for each

q1a = ""  # Python is primarily compiled?
q1b = ""  # Variable names can start with a digit?
q1c = ""  # Strings are mutable?
q1d = ""  # 7 / 3 returns int?
q1e = ""  # Lists can contain different types?

# Optional: Add explanations for False answers as comments
# q1a explanation: ...

# ── Check ──
for name, val in [('q1a',q1a),('q1b',q1b),('q1c',q1c),('q1d',q1d),('q1e',q1e)]:
    if val.upper() in ('T','F'): print(f"  {name} = {val.upper()} ✓")
    else: print(f"  {name} = ??? ← write T or F")

# %% [markdown]
# ---
# ## Question 2 — Predict the Output *(20 points)*
#
# Write the **exact output** of each code snippet as a string. For multiple lines, use `\n`.

# %% [markdown]
# **a) (5 points)** What does this print?
# ```python
# x = 10
# x += 3
# x *= 2
# print(x)
# ```

# %%
# 📝 [Q2a]
q2a = ""  # Write the output, e.g. "42"

# %% [markdown]
# **b) (5 points)** What does this print?
# ```python
# message = "Python"
# print(message[0], message[-1], message[1:4])
# ```

# %%
# 📝 [Q2b]
q2b = ""  # Write the output

# %% [markdown]
# **c) (5 points)** What does this print? *(Two lines — use `\n` between them)*
# ```python
# nums = [10, 20, 30, 40, 50]
# print(nums[::2])
# print(nums[::-1])
# ```

# %%
# 📝 [Q2c]
q2c = ""  # Two lines: "line1\nline2"

# %% [markdown]
# **d) (5 points)** What does this print?
# ```python
# for i in range(1, 8):
#     if i % 3 == 0:
#         print(i, end=" ")
# ```

# %%
# 📝 [Q2d]
q2d = ""  # Write the output

# %% [markdown]
# ---
# ## Question 3 — Write Functions *(20 points)*
#
# Implement the requested functions. Your code will be **auto-tested** against hidden test cases.

# %% [markdown]
# **a) (10 points)** Write a function `even_sum(lst)` that takes a list of integers and returns the **sum of even numbers**.
#
# ```
# even_sum([1, 2, 3, 4, 5, 6])  →  12
# even_sum([1, 3, 5])            →  0
# even_sum([])                   →  0
# ```

# %%
# 📝 [Q3a]
def even_sum(lst):
    pass  # Replace with your code


# ── Quick self-test (optional) ──
# print(even_sum([1, 2, 3, 4, 5, 6]))  # Expected: 12
# print(even_sum([1, 3, 5]))            # Expected: 0

# %% [markdown]
# **b) (10 points)** Write a function `count_vowels(text)` that returns the **number of vowels** (a, e, i, o, u — case-insensitive).
#
# ```
# count_vowels("Hello World")  →  3
# count_vowels("AEIOU")        →  5
# count_vowels("xyz")          →  0
# ```

# %%
# 📝 [Q3b]
def count_vowels(text):
    pass  # Replace with your code


# ── Quick self-test (optional) ──
# print(count_vowels("Hello World"))  # Expected: 3
# print(count_vowels("AEIOU"))        # Expected: 5

# %% [markdown]
# ---
# ## Question 4 — Big O Analysis *(25 points)*

# %% [markdown]
# **a) (15 points)** Write the **time complexity** of each function using Big O notation.
#
# **i)**
# ```python
# def func_A(data):
#     return data[0] + data[-1]
# ```
#
# **ii)**
# ```python
# def func_B(data):
#     total = 0
#     for x in data:
#         total += x
#     return total
# ```
#
# **iii)**
# ```python
# def func_C(data):
#     n = len(data)
#     for i in range(n):
#         for j in range(n):
#             if data[i] == data[j] and i != j:
#                 return True
#     return False
# ```

# %%
# 📝 [Q4a] Write Big O notation, e.g. "O(n)", "O(n^2)", "O(1)"

q4a_i   = ""  # func_A
q4a_ii  = ""  # func_B
q4a_iii = ""  # func_C

# %% [markdown]
# **b) (10 points)** Sort the following complexities from **fastest to slowest**.
#
# $$O(n^2), \quad O(1), \quad O(n \log n), \quad O(2^n), \quad O(n), \quad O(\log n)$$
#
# Write them as a **comma-separated string**, e.g. `"O(1), O(n), ..."`

# %%
# 📝 [Q4b] Fastest → Slowest, comma-separated

q4b = ""  # e.g. "O(1), O(log n), O(n), ..."

# %% [markdown]
# ---
# ## Question 5 — Short Answer *(15 points)*

# %% [markdown]
# **a) (5 points)** What is the **amortized** time complexity of `list.append()` in Python? Briefly explain why it is considered constant time even though occasional resizes cost O(n).

# %%
# 📝 [Q5a]
q5a = """

"""

# %% [markdown]
# **b) (5 points)** The following code has a bug. Identify the error and explain the fix.
# ```python
# num = input("Enter a number: ")
# result = num * 2
# print("Double:", result)
# ```

# %%
# 📝 [Q5b]
q5b = """

"""

# %% [markdown]
# **c) (5 points)** Explain the **stored-program concept** in one sentence and state who developed it.

# %%
# 📝 [Q5c]
q5c = """

"""

# %% [markdown]
# ---
# ## 📮 Submit Your Quiz
#
# **Before submitting:**
# - Make sure you have **run all answer cells** above.
# - Double-check your student information.
#
# Run the cell below to submit.

# %%
#━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📮 SUBMIT — Run this cell to submit your quiz
#━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

import json, urllib.request, inspect, re

QUIZ_WEEK = "Quiz_01"
QUIZ_URL  = "https://script.google.com/macros/s/AKfycbzYmM8JLietp-2tMYCxQAR_X-vrbz2TrSNz5g0entSzxrqpg_AJ8ap2Q_K-X4bu0ybI0w/exec"

# ── Validate student info ──
try:
    _sid    = STUDENT_ID.strip()
    _sname  = STUDENT_NAME.strip()
    _semail = STUDENT_EMAIL.strip().lower()
    _scode  = CLASS_CODE.strip().upper()
except NameError:
    raise SystemExit("❌ Run the Student Information cell first!")

if not _sid or not _sname or not _semail or not _scode:
    raise SystemExit("❌ Student information is incomplete. Fill in and run the info cell.")

print("📋 Collecting answers...\n")
_answers = {}

# ── Q1: True/False ──
print("Q1 — True/False:")
for _q in ['q1a', 'q1b', 'q1c', 'q1d', 'q1e']:
    try:
        _val = eval(_q)
        _answers[_q] = str(_val).strip().upper()
        print(f"  {_q} = {_answers[_q]}")
    except NameError:
        _answers[_q] = ""
        print(f"  {_q} = ⚠️  not answered")

# ── Q2: Output Prediction ──
print("\nQ2 — Output Prediction:")
for _q in ['q2a', 'q2b', 'q2c', 'q2d']:
    try:
        _val = eval(_q)
        _answers[_q] = str(_val).strip()
        _preview = _answers[_q][:40].replace('\n', '↵')
        print(f"  {_q} = \"{_preview}\"")
    except NameError:
        _answers[_q] = ""
        print(f"  {_q} = ⚠️  not answered")

# ── Q3: Function Tests ──
print("\nQ3 — Function Tests:")

# Q3a: even_sum
try:
    _t = [
        even_sum([1, 2, 3, 4, 5, 6]) == 12,
        even_sum([1, 3, 5]) == 0,
        even_sum([2, 4, 6]) == 12,
        even_sum([]) == 0,
    ]
    _answers['q3a_tests'] = ','.join(str(int(x)) for x in _t)
    try: _answers['q3a_code'] = inspect.getsource(even_sum)
    except: _answers['q3a_code'] = 'could not extract'
    print(f"  q3a: {sum(_t)}/4 tests passed {'✅' if all(_t) else '⚠️'}")
except Exception as _e:
    _answers['q3a_tests'] = '0,0,0,0'
    _answers['q3a_code'] = ''
    print(f"  q3a: 0/4 tests — {type(_e).__name__}: {_e}")

# Q3b: count_vowels
try:
    _t = [
        count_vowels("Hello World") == 3,
        count_vowels("aeiou") == 5,
        count_vowels("AEIOU") == 5,
        count_vowels("xyz") == 0,
    ]
    _answers['q3b_tests'] = ','.join(str(int(x)) for x in _t)
    try: _answers['q3b_code'] = inspect.getsource(count_vowels)
    except: _answers['q3b_code'] = 'could not extract'
    print(f"  q3b: {sum(_t)}/4 tests passed {'✅' if all(_t) else '⚠️'}")
except Exception as _e:
    _answers['q3b_tests'] = '0,0,0,0'
    _answers['q3b_code'] = ''
    print(f"  q3b: 0/4 tests — {type(_e).__name__}: {_e}")

# ── Q4: Big O ──
print("\nQ4 — Big O Analysis:")
for _q in ['q4a_i', 'q4a_ii', 'q4a_iii', 'q4b']:
    try:
        _val = eval(_q)
        _answers[_q] = str(_val).strip()
        print(f"  {_q} = \"{_answers[_q]}\"")
    except NameError:
        _answers[_q] = ""
        print(f"  {_q} = ⚠️  not answered")

# ── Q5: Short Answer ──
print("\nQ5 — Short Answer:")
for _q in ['q5a', 'q5b', 'q5c']:
    try:
        _val = eval(_q)
        _answers[_q] = str(_val).strip()
        _ok = '✓' if len(_answers[_q]) > 5 else '⚠️  too short'
        print(f"  {_q}: {_ok} ({len(_answers[_q])} chars)")
    except NameError:
        _answers[_q] = ""
        print(f"  {_q} = ⚠️  not answered")

# ── Summary ──
_answered = sum(1 for k, v in _answers.items()
               if not k.endswith('_tests') and not k.endswith('_code') and v.strip())
print(f"\n{'─'*50}")
print(f"📊 {_answered}/16 questions answered")

if _answered == 0:
    raise SystemExit("❌ No answers found! Run your answer cells first.")

# ── Build payload & send ──
_data = json.dumps({
    "week": QUIZ_WEEK,
    "studentId": _sid,
    "studentName": _sname,
    "studentEmail": _semail,
    "classCode": _scode,
    "source": "quiz-notebook",
    "answers": _answers
}).encode("utf-8")

print("\n📡 Submitting...")

try:
    _req = urllib.request.Request(
        QUIZ_URL, data=_data,
        headers={"Content-Type": "text/plain"}, method="POST"
    )
    _resp = urllib.request.urlopen(_req, timeout=30)
    _result = json.loads(_resp.read().decode())

    if _result.get("success"):
        _auto = _result.get('autoScore', '?')
        _max  = _result.get('totalMax', '?')
        print(f"\n{'═'*50}")
        print(f"  ✅ SUBMITTED SUCCESSFULLY!")
        print(f"  📊 Auto-graded score: {_auto} / {_max}")
        print(f"  📧 Check your email for detailed results.")
        print(f"{'═'*50}")

        _details = _result.get('details', {})
        if _details:
            print("\n  Per-question breakdown:")
            for _qid in sorted(_details.keys()):
                _d = _details[_qid]
                _icon = '✅' if _d['status'] == 'correct' else \
                        '🟡' if 'partial' in _d['status'] else \
                        '⬜' if _d['status'] == 'missing' else '❌'
                print(f"    {_icon} {_qid}: {_d['earned']}/{_d['max']} — {_d['status']}")
    else:
        print(f"\n❌ {_result.get('message', 'Submission failed')}")

except Exception as _e:
    try:
        _req = urllib.request.Request(QUIZ_URL, data=_data,
            headers={"Content-Type": "text/plain"}, method="POST")
        urllib.request.urlopen(_req, timeout=10)
    except: pass
    print(f"\n⚠️  Request sent — check your email for confirmation.")
    print(f"   (If no email arrives, try again or contact your instructor)")
